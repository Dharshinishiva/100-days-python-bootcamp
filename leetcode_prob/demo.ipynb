# %%
n=121
a=str(n)
print(a)
# Out:
# 121

# %%
n=-121
a=list(str(n))
print(a)
# Out:
# ['-', '1', '2', '1']

# %%
b=a[::-1]
print(b)
# Out:
# ['1', '2', '1', '-']

# %%
if a==b:
    print("True")
else:
    print("false")
# Out:
# false
